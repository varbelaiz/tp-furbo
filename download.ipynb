# %%
# !pip install soccernet
# Out:
# ...
# WARNING: huggingface-hub 1.1.4 does not provide the extra 'cli'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 39.0 MB/s eta 0:00:0000:010:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 60.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 122.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 137.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
# ...

# %%
from SoccerNet.Downloader import SoccerNetDownloader

# %%
mySoccerNetDownloader = SoccerNetDownloader(LocalDirectory="data")

# %%
mySoccerNetDownloader.downloadDataTask(task="tracking", split=["train","test","valid"])
